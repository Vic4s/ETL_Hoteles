# %%
# pip install psycopg2
# !pip install SQLAlchemy

# %%
import pandas as pd
import psycopg2 
from psycopg2 import sql
from sqlalchemy import create_engine, text
import sqlalchemy

# %%
# Crear la conexión con SQLAlchemy
engine = create_engine("postgresql+psycopg2://postgres:admin@localhost:5432/hoteles")
conn_alchemy = engine.connect()

# %%
# Configurar la conexión
conn_ps = psycopg2.connect(
    dbname="hoteles",
    user="postgres",
    password="admin",
    host="localhost",
    port="5432"
)

# Crear un cursor para ejecutar comandos SQL
cur = conn_ps.cursor()

# Verificar la conexión
cur.execute("SELECT version();")
print(cur.fetchone())

# # Cerrar la conexión
# cur.close()
# conn.close()
# Out:
# ('PostgreSQL 16.4, compiled by Visual C++ build 1940, 64-bit',)

# %% [markdown]
# # CREAR DATAFRAMES DE LAS TABLAS

# %%
df_hoteles = pd.read_pickle("../data/limpieza/hoteles.pkl")
df_hoteles
# Out:
#                                  id_reserva id_cliente          nombre  \
# 0      40c4cb55-d1f5-407b-832f-4756b8ff77b4       9063           Maite
# 1      f2ce8df5-7844-43e1-8c0f-97ce7a208f21      13646           Tecla
# 2      57d4515a-447d-4067-afcb-9bdcf4e4e915        993         Amílcar
# 3      ccbd9fe9-5a60-4f6f-bed3-73a7158ecba7       7371            Joan
# 4      99c3dc4f-663c-45f7-849a-ac9313f3746a       2839           Chelo
# ...                                     ...        ...             ...
# 14995  e856adee-838c-4031-920c-05ec5f1e32e6       7312          Jesusa
# 14996  77134049-6e4f-49b0-a6f8-93b7466b1c22       3479            Cruz
# 14997  19aef6f3-3e85-4719-9dff-b768d9bfe5a9       7539  Jose Francisco
# 14998  aa092c3e-7fe6-4985-a5a8-cacd38554b1b      13982            Toño
# 14999  6d1f590c-ae87-4582-bc99-9b8cbf1d8e28       3524        Custodia
#
#         apellido                               mail  competencia  \
# ...

# %%
df_hoteles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id_reserva            15000 non-null  object
#  1   id_cliente            15000 non-null  object
#  2   nombre                15000 non-null  object
#  3   apellido              15000 non-null  object
#  4   mail                  15000 non-null  object
#  5   competencia           15000 non-null  bool
#  6   fecha_reserva         15000 non-null  datetime64[ns]
#  7   inicio_estancia       15000 non-null  datetime64[ns]
#  8   final_estancia        15000 non-null  datetime64[ns]
#  9   id_hotel              15000 non-null  int64
#  10  precio_noche          15000 non-null  float64
#  11  nombre_hotel          15000 non-null  object
#  12  valoracion            15000 non-null  float64
#  13  ciudad                15000 non-null  object
# ...

# %% [markdown]
# ## TABLA EVENTOS

# %%
df_eventos = pd.read_pickle("../data/api/eventos_madrid.pkl")
df_eventos
# Out:
#      id_evento                                      nombre_evento  \
# 0     12677513            25º aniversario de la revista La Fragua
# 1     12693864       60 Premio Reina Sofía de Pintura y Escultura
# 2     12534372                                        A toda vela
# 3     12536930          Acompañamiento digital a personas mayores
# 4     12622331                            Acompañar en la pérdida
# ..         ...                                                ...
# 224   12581317                                Y tú, ¿cómo viajas?
# 225   12679923                         Yoga para el buen trato II
# 226   12677266  'Lina en el mundo de Paul Klee' por Alejandra ...
# 227   12679855                     'Refugiados' por Myriam Laguía
# 228   12569977              ¡Ahora nos toca jugar! Juegos de mesa
#
#                                             url_evento  codigo_postal  \
# 0    http://www.madrid.es/sites/v/index.jsp?vgnextc...          28005
# ...

# %%
df_eventos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_evento      229 non-null    int64
#  1   nombre_evento  229 non-null    object
#  2   url_evento     229 non-null    object
#  3   codigo_postal  229 non-null    int64
#  4   direccion      229 non-null    object
#  5   horario        229 non-null    object
#  6   fecha_inicio   229 non-null    datetime64[ns]
#  7   fecha_fin      229 non-null    datetime64[ns]
#  8   organizacion   229 non-null    object
#  9   id_ciudad      229 non-null    int64
# dtypes: datetime64[ns](2), int64(3), object(5)
# memory usage: 18.0+ KB

# %%
df_eventos.to_sql("eventos", con=engine, if_exists="replace", index=False)
# Out:
# 229

# %%
result = conn_alchemy.execute(text("SELECT * FROM eventos")).fetchall()

type(result)
# Out:
# list

# %%
# Ejecutar la consulta SQL para obtener los registros de eventos
result = conn_alchemy.execute(text("SELECT nombre_evento, organizacion FROM eventos"))  # Selecciona todos los eventos
eventos = result.fetchall()  # Obtener todos los registros

# Convertir los resultados en un DataFrame para visualización
df_eventos_resultados = pd.DataFrame(eventos, columns=result.keys())

# %%
df_eventos_resultados
# Out:
#                                          nombre_evento  \
# 0              25º aniversario de la revista La Fragua
# 1         60 Premio Reina Sofía de Pintura y Escultura
# 2                                          A toda vela
# 3            Acompañamiento digital a personas mayores
# 4                              Acompañar en la pérdida
# ..                                                 ...
# 224                                Y tú, ¿cómo viajas?
# 225                         Yoga para el buen trato II
# 226  'Lina en el mundo de Paul Klee' por Alejandra ...
# 227                     'Refugiados' por Myriam Laguía
# 228              ¡Ahora nos toca jugar! Juegos de mesa
#
#                                           organizacion
# 0    Biblioteca Pública Municipal Iván de Vargas (C...
# 1               Centro Cultural Casa de Vacas (Retiro)
# 2                                      Matadero Madrid
# 3                                     Sin organizacion
# ...

# %%
result = conn_alchemy.execute(text("SELECT * FROM eventos")).fetchall()
print(result)
print(len(result))
# Out:
# [(12677513, '25º aniversario de la revista La Fragua', 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=1ea220bed10d4910VgnVCM2000001f4a900aRCRD', 28005, 'CALLE SAN JUSTO 5', 'Sin horario', datetime.datetime(2025, 2, 24, 0, 0), datetime.datetime(2025, 3, 2, 0, 0), 'Biblioteca Pública Municipal Iván de Vargas (Centro)', 1), (12693864, '60 Premio Reina Sofía de Pintura y Escultura', 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=34c5130393e15910VgnVCM2000001f4a900aRCRD', 28009, 'PASEO COLOMBIA 1', 'Sin horario', datetime.datetime(2025, 2, 27, 0, 0), datetime.datetime(2025, 3, 23, 0, 0), 'Centro Cultural Casa de Vacas (Retiro)', 1), (12534372, 'A toda vela', 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=59d5e7da8b822910VgnVCM1000001d4a900aRCRD', 28045, 'PLAZA LEGAZPI 8', 'Sin horario', datetime.datetime(2024, 10, 1, 
# ...

# %% [markdown]
# ## TABLA CIUDAD

# %%
data_to_insert_ciudad =["Madrid"]

# %% [markdown]
# ## TABLA HOTELES

# %%
df_tabla_hoteles = df_hoteles[["nombre_hotel", "competencia", "valoracion", "id_ciudad" ]]
df_tabla_hoteles
# Out:
#                                nombre_hotel  competencia  valoracion  \
# 0                         Hotel Monte Verde        False        3.10
# 1                      Hotel Brisas del Mar        False        3.09
# 2                      Hotel Camino del Sol        False        3.07
# 3                    Hotel Puerta del Cielo        False        3.03
# 4                        Hotel Encanto Real        False        3.03
# ...                                     ...          ...         ...
# 14995           ibis budget Madrid Vallecas         True        4.30
# 14996       ibis budget Madrid Calle Alcalá         True        4.30
# 14997  Novotel Madrid Campo de las Naciones         True        4.50
# 14998  ibis budget Madrid Centro las Ventas         True        4.30
# 14999        ibis Madrid Aeropuerto Barajas         True        4.40
#
#        id_ciudad
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# ...

# %%
df_tabla_hoteles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nombre_hotel  15000 non-null  object
#  1   competencia   15000 non-null  bool
#  2   valoracion    15000 non-null  float64
#  3   id_ciudad     15000 non-null  int64
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 366.3+ KB

# %% [markdown]
# ## TABLA RESERVAS

# %%
df_tabla_reservas = df_hoteles[["id_reserva", "fecha_reserva", "inicio_estancia", "final_estancia", "precio_noche","id_cliente", "id_hotel"]]
df_tabla_reservas
# Out:
#                                  id_reserva fecha_reserva inicio_estancia  \
# 0      40c4cb55-d1f5-407b-832f-4756b8ff77b4    2025-02-09      2025-03-01
# 1      f2ce8df5-7844-43e1-8c0f-97ce7a208f21    2025-02-08      2025-03-01
# 2      57d4515a-447d-4067-afcb-9bdcf4e4e915    2025-02-02      2025-03-01
# 3      ccbd9fe9-5a60-4f6f-bed3-73a7158ecba7    2025-02-08      2025-03-01
# 4      99c3dc4f-663c-45f7-849a-ac9313f3746a    2025-02-09      2025-03-01
# ...                                     ...           ...             ...
# 14995  e856adee-838c-4031-920c-05ec5f1e32e6    2025-02-26      2025-03-01
# 14996  77134049-6e4f-49b0-a6f8-93b7466b1c22    2025-02-26      2025-03-01
# 14997  19aef6f3-3e85-4719-9dff-b768d9bfe5a9    2025-02-26      2025-03-01
# 14998  aa092c3e-7fe6-4985-a5a8-cacd38554b1b    2025-02-26      2025-03-01
# 14999  6d1f590c-ae87-4582-bc99-9b8cbf1d8e28    2025-02-26      2025-03-01
#
#       final_estancia  precio_noche id_cliente  id_hotel
# ...

# %%
df_tabla_reservas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_reserva       15000 non-null  object
#  1   fecha_reserva    15000 non-null  datetime64[ns]
#  2   inicio_estancia  15000 non-null  datetime64[ns]
#  3   final_estancia   15000 non-null  datetime64[ns]
#  4   precio_noche     15000 non-null  float64
#  5   id_cliente       15000 non-null  object
#  6   id_hotel         15000 non-null  int64
# dtypes: datetime64[ns](3), float64(1), int64(1), object(2)
# memory usage: 820.4+ KB

# %% [markdown]
# ## TABLA CLIENTES

# %%
df_tabla_clientes = df_hoteles[["id_cliente", "nombre", "apellido", "mail"]]
df_tabla_clientes
# Out:
#       id_cliente          nombre   apellido                               mail
# 0           9063           Maite  Calatayud        maite.calatayud@example.com
# 1          13646           Tecla      Bonet            tecla.bonet@example.com
# 2            993         Amílcar     Andrés         amílcar.andrés@example.com
# 3           7371            Joan    Vazquez           joan.vazquez@example.com
# 4           2839           Chelo       Flor             chelo.flor@example.com
# ...          ...             ...        ...                                ...
# 14995       7312          Jesusa   Espinosa        jesusa.espinosa@example.com
# 14996       3479            Cruz    Hurtado           cruz.hurtado@example.com
# 14997       7539  Jose Francisco     Cortes  jose francisco.cortes@example.com
# 14998      13982            Toño    Narváez           toño.narváez@example.com
# 14999       3524        Custodia      Marco         custodia.marco@example.com
#
# ...

# %%
df_tabla_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_cliente  15000 non-null  object
#  1   nombre      15000 non-null  object
#  2   apellido    15000 non-null  object
#  3   mail        15000 non-null  object
# dtypes: object(4)
# memory usage: 468.9+ KB
